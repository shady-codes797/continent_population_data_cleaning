# %%
import pandas as pd

# %%
pop_url = "https://raw.githubusercontent.com/datasets/population/master/data/population.csv"
df = pd.read_csv(pop_url)

# %%
df.head()
# Out:
#   Country Name Country Code  Year    Value
# 0        Aruba          ABW  1960  54922.0
# 1        Aruba          ABW  1961  55578.0
# 2        Aruba          ABW  1962  56320.0
# 3        Aruba          ABW  1963  57002.0
# 4        Aruba          ABW  1964  57619.0

# %%
df.rename(columns={"Value": "Population"}, inplace=True)

# %%
continent_url = "https://raw.githubusercontent.com/dbouquin/IS_608/master/NanosatDB_munging/Countries-Continents.csv"
continent_df = pd.read_csv(continent_url)

# %%
continent_df.head()
# Out:
#   Continent   Country
# 0    Africa   Algeria
# 1    Africa    Angola
# 2    Africa     Benin
# 3    Africa  Botswana
# 4    Africa   Burkina

# %%
continent_df.rename(columns={
    "Country": "Country Name",
    "Continent": "Continent"
}, inplace=True)

# %%
merged_df = df.merge(continent_df, on="Country Name", how="left")

# %%
merged_df.head()
# Out:
#   Country Name Country Code  Year  Population Continent
# 0        Aruba          ABW  1960     54922.0       NaN
# 1        Aruba          ABW  1961     55578.0       NaN
# 2        Aruba          ABW  1962     56320.0       NaN
# 3        Aruba          ABW  1963     57002.0       NaN
# 4        Aruba          ABW  1964     57619.0       NaN

# %%
latest_year = merged_df["Year"].max()
latest_df = merged_df[merged_df["Year"] == latest_year]

# %%
latest_latest_df = latest_df.sort_values(by="Population", ascending=False)
df = latest_df.dropna(subset=["Continent"])

# %%
top5_per_continent = (
    latest_df
    .groupby("Continent")
    .head(5)
    [["Continent", "Country Name", "Population"]]
)

# %%
top5_per_continent
# Out:
#            Continent              Country Name   Population
# 191             Asia               Afghanistan   41454761.0
# 319           Africa                    Angola   36749906.0
# 383           Europe                   Albania    2745972.0
# 447           Europe                   Andorra      80856.0
# 575             Asia      United Arab Emirates   10483751.0
# 639    South America                 Argentina   45538401.0
# 703           Europe                   Armenia    2990900.0
# 831    North America       Antigua and Barbuda      93316.0
# 895          Oceania                 Australia   26658948.0
# 959           Europe                   Austria    9131761.0
# 1023          Europe                Azerbaijan   10153958.0
# 1087          Africa                   Burundi   13689450.0
# 1215          Africa                     Benin   14111034.0
# 1343            Asia                Bangladesh  171466990.0
# 1471            Asia                   Bahrain    1577059.0
# 1727   North America                    Belize     411106.0
# 1855   South America                   Bolivia   12244159.0
# 1919   South America                    Brazil  211140729.0
# 1983   North America                  Barbados     282336.0
# 2111            Asia                    Bhutan     786385.0
# 2175          Africa                  Botswana    2480244.0
# 2239          Africa  Central African Republic    5152421.0
# 2303   North America                    Canada   40097761.0
# 2559   South America                     Chile   19658835.0
# 2943   South America                  Colombia   52321152.0
# 3135   North America                Costa Rica    5105525.0
# 4927         Oceania                      Fiji     924145.0
# 7935         Oceania                  Kiribati     132530.0
# 9919         Oceania          Marshall Islands      38827.0
# 11455        Oceania                     Nauru      11875.0

# %%
final_df = top5_per_continent.copy()
final_df.rename(columns={
    "Country Name": "Country",
    "Population": "Population"
}, inplace=True)

# %%
final_df = final_df.reset_index(drop=True)
final_df
# Out:
#         Continent                   Country   Population
# 0            Asia               Afghanistan   41454761.0
# 1          Africa                    Angola   36749906.0
# 2          Europe                   Albania    2745972.0
# 3          Europe                   Andorra      80856.0
# 4            Asia      United Arab Emirates   10483751.0
# 5   South America                 Argentina   45538401.0
# 6          Europe                   Armenia    2990900.0
# 7   North America       Antigua and Barbuda      93316.0
# 8         Oceania                 Australia   26658948.0
# 9          Europe                   Austria    9131761.0
# 10         Europe                Azerbaijan   10153958.0
# 11         Africa                   Burundi   13689450.0
# 12         Africa                     Benin   14111034.0
# 13           Asia                Bangladesh  171466990.0
# 14           Asia                   Bahrain    1577059.0
# 15  North America                    Belize     411106.0
# 16  South America                   Bolivia   12244159.0
# 17  South America                    Brazil  211140729.0
# 18  North America                  Barbados     282336.0
# 19           Asia                    Bhutan     786385.0
# 20         Africa                  Botswana    2480244.0
# 21         Africa  Central African Republic    5152421.0
# 22  North America                    Canada   40097761.0
# 23  South America                     Chile   19658835.0
# 24  South America                  Colombia   52321152.0
# 25  North America                Costa Rica    5105525.0
# 26        Oceania                      Fiji     924145.0
# 27        Oceania                  Kiribati     132530.0
# 28        Oceania          Marshall Islands      38827.0
# 29        Oceania                     Nauru      11875.0

# %%
final_df = final_df.sort_values(
    by=["Continent", "Population"],
    ascending=[True, False]
)

# %%
final_df = final_df.reset_index(drop=True)
final_df.index = final_df.index + 1

# %%
final_df
# Out:
#         Continent                   Country   Population
# 1          Africa                    Angola   36749906.0
# 2          Africa                     Benin   14111034.0
# 3          Africa                   Burundi   13689450.0
# 4          Africa  Central African Republic    5152421.0
# 5          Africa                  Botswana    2480244.0
# 6            Asia                Bangladesh  171466990.0
# 7            Asia               Afghanistan   41454761.0
# 8            Asia      United Arab Emirates   10483751.0
# 9            Asia                   Bahrain    1577059.0
# 10           Asia                    Bhutan     786385.0
# 11         Europe                Azerbaijan   10153958.0
# 12         Europe                   Austria    9131761.0
# 13         Europe                   Armenia    2990900.0
# 14         Europe                   Albania    2745972.0
# 15         Europe                   Andorra      80856.0
# 16  North America                    Canada   40097761.0
# 17  North America                Costa Rica    5105525.0
# 18  North America                    Belize     411106.0
# 19  North America                  Barbados     282336.0
# 20  North America       Antigua and Barbuda      93316.0
# 21        Oceania                 Australia   26658948.0
# 22        Oceania                      Fiji     924145.0
# 23        Oceania                  Kiribati     132530.0
# 24        Oceania          Marshall Islands      38827.0
# 25        Oceania                     Nauru      11875.0
# 26  South America                    Brazil  211140729.0
# 27  South America                  Colombia   52321152.0
# 28  South America                 Argentina   45538401.0
# 29  South America                     Chile   19658835.0
# 30  South America                   Bolivia   12244159.0

# %%
final_df.to_csv("top_5_countries_per_continent.csv", index=True)
